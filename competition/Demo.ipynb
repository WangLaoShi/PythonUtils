# %%
import pandas as pd
import numpy as np

datas = pd.read_csv("LincolnTemp.csv")

print(datas)
# Out:
#         Unnamed: 0  order_date  sales_region_code  item_code  first_cate_code  \
# 0                0  2015-09-01                104      22069              307
# 1                1  2015-09-01                104      20028              301
# 2                2  2015-09-02                104      21183              307
# 3                3  2015-09-02                104      20448              308
# 4                4  2015-09-02                104      21565              307
# ...            ...         ...                ...        ...              ...
# 582609      597689  2018-12-20                102      20994              302
# 582610      597690  2018-12-20                102      21875              302
# 582611      597691  2018-12-20                102      20215              302
# 582612      597692  2018-12-20                102      20195              302
# 582613      597693  2018-12-20                102      20321              302
#
#         second_cate_code  sales_chan_name  item_price  ord_qty  dayofmonth  \
# 0                    403                0      1114.0       19           1
# 1                    405                0      1012.0       12           1
# 2                    403                1       428.0      109           2
# 3                    404                1       962.0        3           2
# 4                    403                0      1400.0        3           2
# ...                  ...              ...         ...      ...         ...
# 582609               408                0       843.0       59          20
# 582610               408                0       762.0      502          20
# 582611               408                0      2013.0      106          20
# 582612               408                0      2120.0      187          20
# 582613               408                0      1244.0      205          20
#
#         ...  year  is_month_start  is_month_end  is_workday  is_holiday  \
# 0       ...  2015               1             0           1           0
# 1       ...  2015               1             0           1           0
# 2       ...  2015               0             0           1           0
# 3       ...  2015               0             0           1           0
# 4       ...  2015               0             0           1           0
# ...     ...   ...             ...           ...         ...         ...
# 582609  ...  2018               0             0           1           0
# 582610  ...  2018               0             0           1           0
# 582611  ...  2018               0             0           1           0
# 582612  ...  2018               0             0           1           0
# 582613  ...  2018               0             0           1           0
#
#         in_quarter  in_month_stage  month_num  region_chan  \
# 0                3               0          0        104-0
# 1                3               0          0        104-0
# 2                3               0          0        104-1
# 3                3               0          0        104-1
# 4                3               0          0        104-0
# ...            ...             ...        ...          ...
# 582609           4               1         39        102-0
# 582610           4               1         39        102-0
# 582611           4               1         39        102-0
# 582612           4               1         39        102-0
# 582613           4               1         39        102-0
#
#         segements_item_price
# 0               (1000, 1500]
# 1               (1000, 1500]
# 2                   (0, 500]
# 3                (500, 1000]
# 4               (1000, 1500]
# ...                      ...
# 582609           (500, 1000]
# 582610           (500, 1000]
# 582611     (1500, 100000000]
# 582612     (1500, 100000000]
# 582613          (1000, 1500]
#
# [582614 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
datas.columns
# Out:
# Index(['Unnamed: 0', 'order_date', 'sales_region_code', 'item_code',
#        'first_cate_code', 'second_cate_code', 'sales_chan_name', 'item_price',
#        'ord_qty', 'dayofmonth', 'dayofweek', 'month', 'year', 'is_month_start',
#        'is_month_end', 'is_workday', 'is_holiday', 'in_quarter',
#        'in_month_stage', 'month_num', 'region_chan', 'segements_item_price'],
#       dtype='object')

# %%
X = datas[['sales_region_code', 'item_code',
       'first_cate_code', 'second_cate_code', 'sales_chan_name',]]
y = datas['ord_qty']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
import os
import sys
 
cur_dir = os.getcwd()
print("cur_dir",cur_dir)
pkg_rootdir = os.path.dirname(os.path.dirname(cur_dir))
# print(pkg_rootdir)
if pkg_rootdir not in sys.path:
    sys.path.append(pkg_rootdir)
sys.path.append('/Users/lincolnmac16/Documents/GitHub/PythonUtils/')
print(sys.path)
# Out:
# cur_dir /Users/lincolnmac16/Documents/GitHub/PythonUtils/competition
# ['/Users/lincolnmac16/Documents/GitHub/PythonUtils/competition', '/Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python38.zip', '/Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python3.8', '/Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python3.8/lib-dynload', '', '/Users/lincolnmac16/.local/lib/python3.8/site-packages', '/Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python3.8/site-packages', '/Users/lincolnmac16/Documents/GitHub', '/Users/lincolnmac16/Documents/GitHub/PythonUtils/']

# %%
from machine_learning.ml_result.MLResult import *

# %%
rgs_ml_scores(X_train,y_train,X_test, y_test)
# Out:
# 当前运行参数------->
# 算法  Linear (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> Linear
# MSE train: 11536.651, test: 11603.193
# R^2 train: 0.027, test: 0.027
# 当前运行参数------->
# 算法  Ridge (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> Ridge
# MSE train: 11536.651, test: 11603.194
# R^2 train: 0.027, test: 0.027
# 当前运行参数------->
# 算法  Lasso (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> Lasso
# MSE train: 11536.815, test: 11603.444
# R^2 train: 0.027, test: 0.027
# 当前运行参数------->
# 算法  Elastic (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> Elastic
# MSE train: 11571.938, test: 11639.926
# R^2 train: 0.024, test: 0.024
# 当前运行参数------->
# 算法  DecisionTree (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> DecisionTree
# MSE train: 9393.373, test: 9588.497
# R^2 train: 0.208, test: 0.196
# 当前运行参数------->
# 算法  KNN (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> KNN
# MSE train: 11170.305, test: 11296.311
# R^2 train: 0.058, test: 0.053
# 当前运行参数------->
# 算法  Bagging (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> Bagging
# MSE train: 9403.702, test: 9584.240
# R^2 train: 0.207, test: 0.197
# 当前运行参数------->
# 算法  RF (407829, 5) (174785, 5)
# 当前运行参数------->
# /Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
#  Regression method-----> RF
# MSE train: 9404.401, test: 9588.650
# R^2 train: 0.207, test: 0.196
# 当前运行参数------->
# 算法  ExtraTree (407829, 5) (174785, 5)
# 当前运行参数------->
# /Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
#  Regression method-----> ExtraTree
# MSE train: 9393.373, test: 9587.607
# R^2 train: 0.208, test: 0.196
# 当前运行参数------->
# 算法  ADA (407829, 5) (174785, 5)
# 当前运行参数------->
# /Users/lincolnmac16/opt/anaconda3/envs/PythonUtils/lib/python3.8/site-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
#  Regression method-----> ADA
# MSE train: 12933.031, test: 12979.949
# R^2 train: -0.090, test: -0.088
# 当前运行参数------->
# 算法  GB (407829, 5) (174785, 5)
# 当前运行参数------->
#  Regression method-----> GB
# MSE train: 10777.538, test: 10847.084
# R^2 train: 0.091, test: 0.091
